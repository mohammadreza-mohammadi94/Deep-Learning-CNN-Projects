# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadreza-mohammadi94/Deep-Learning-CNN-Projects/blob/master/Flower-Images-MobileNet-Edge-Optimization/edge_optimization_flower_images_tflite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import tensorflow as tf
import numpy as np
import os
import pathlib

# %% [markdown]
# # Load Data

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir) / 'flower_photos'
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step

# %% [markdown]
# # Loading Datasets

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training", seed=123,
    image_size=IMG_SIZE, batch_size=BATCH_SIZE
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="validation", seed=123,
    image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

def preprocess(image, label):
    return tf.keras.applications.mobilenet_v2.preprocess_input(image), label

train_ds = train_ds.map(preprocess).cache().prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.map(preprocess).cache().prefetch(tf.data.AUTOTUNE)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %% [markdown]
# # Load `MobileNetV2`

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=IMG_SIZE + (3,), include_top=False, weights='imagenet'
)
base_model.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(5, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_ds, epochs=5, validation_data=val_ds, verbose=1)

model.save("flower_model_float.keras")
float_size = os.path.getsize("flower_model_float.keras") / (1024*1024)
print(f"Base Model Size: {float_size:.2f} MB")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 71s 532ms/step - accuracy: 0.5810 - loss: 1.0876 - val_accuracy: 0.8406 - val_loss: 0.4392
# Epoch 2/5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8536 - loss: 0.4230 - val_accuracy: 0.8665 - val_loss: 0.3645
# Epoch 3/5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8851 - loss: 0.3426 - val_accuracy: 0.8896 - val_loss: 0.3368
# Epoch 4/5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9029 - loss: 0.2812 - val_accuracy: 0.8869 - val_loss: 0.3208
# Epoch 5/5
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9164 - loss: 0.2527 - val_accuracy: 0.8937 - val_loss: 0.3085
# Base Model Size: 9.25 MB

# %% [markdown]
# # Representative Dataset

# %%
def representative_data_gen():
    for input_value, _ in train_ds.unbatch().batch(1).take(100):
        yield [input_value]

print("Representative dataset generator ready.")
# Out:
# Representative dataset generator ready.

# %%
# Full Integer TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]

converter.representative_dataset = representative_data_gen

converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]


converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model_quant = converter.convert()

QUANT_FILE = "flower_model_full_int8.tflite"
with open(QUANT_FILE, 'wb') as f:
    f.write(tflite_model_quant)

quant_size = os.path.getsize(QUANT_FILE) / (1024*1024)
print(f"Full Integer Model Saved: {quant_size:.2f} MB")
# Out:
# Saved artifact at '/tmp/tmp27yojwej'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   135934191807632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191808016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191810320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191809936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191809360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191807824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191810512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191811280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191810896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191808208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191810128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191812240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191808976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191809744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934191809552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185570960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185573072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185573264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185572112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185571536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185570768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185574416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185574608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185573840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185571344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185573456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185571920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185572880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185574032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185575568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185574992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185575184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185575376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185574224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185576528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185575952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185576144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185576336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185572304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185577488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185577872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185578064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185577104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185577680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185578640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185579024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185579216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185578256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185578832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185579792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185577296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185579408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185579600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185576720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185580752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185580176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185580368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185580560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185576912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185581712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185581136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185581328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185581520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185578448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185582672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185582096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185582288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185582480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185579984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185583632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185583056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185583248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185583440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185580944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185584592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185584016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185584208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185584400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185581904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185585552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185584976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185585168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185585936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185582864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185586512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185585360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185586128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185583824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185586320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185585744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934185584784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172661328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172661520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172660752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172660176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172659984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172661136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172660944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172660560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172662480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172661904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172662096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172662288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172659792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172663440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172662864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172663056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172663248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172660368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172664400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172663824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172664016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172664208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172661712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172665360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172664784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172664976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172665168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172662672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172666320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172665744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172665936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172666128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172663632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172667280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172666704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172666896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172667088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172664592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172668240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172667664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172667856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172668048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172665552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172669200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172668624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172668816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172669008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172666512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172670160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172669584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172669776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172669968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172667472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172671120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172670544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172670736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172670928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172668432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172672080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172671504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172671696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172671888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172669392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172673040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172672464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172672656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172672848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172670352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172674000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172673424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172673616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172673808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172671312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172674960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172674384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172674576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172675344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172672272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172675920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172674768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172675536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172673232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172675728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172675152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934172674192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173480528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173480720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173479952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173479376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173479184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173480336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173480144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173479760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173481680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173481104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173481296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173481488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173478992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173482640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173482064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173482256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173482448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173479568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173483600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173483024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173483216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173483408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173480912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173484560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173483984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173484176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173484368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173481872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173485520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173484944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173485136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173485328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173482832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173486480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173485904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173486096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173486288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173483792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173487440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173486864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173487056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173487248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173484752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173488400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173487824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173488016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173488208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173485712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173489360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173488784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173488976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173489168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173486672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173490320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173489744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173489936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173490128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173487632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173491280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173490704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173490896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173491088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173488592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173492240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173491664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173491856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173492048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173489552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173493200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173492624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173492816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173493008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173490512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173494160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173493584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173493776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173494544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173491472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173495120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173493968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173494736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173492432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173494928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934173494352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934095786640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135934095787600: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Full Integer Model Saved: 2.59 MB

# %% [markdown]
# # Evaluation

# %%
def evaluate_int8_model(model_path, dataset):
    interpreter = tf.lite.Interpreter(model_path=model_path)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()[0]
    output_details = interpreter.get_output_details()[0]


    input_scale, input_zero_point = input_details["quantization"]

    print(f"Model Input Type: {input_details['dtype']}")
    print(f"Input Scale: {input_scale}, Zero Point: {input_zero_point}")

    correct = 0
    total = 0

    print("Running inference (converting float images to int8)...")


    for image_float, label in dataset.unbatch().take(200):

        image_float = tf.expand_dims(image_float, axis=0).numpy()
        image_int8 = (image_float / input_scale) + input_zero_point
        image_int8 = np.clip(image_int8, -128, 127).astype(np.int8)

        interpreter.set_tensor(input_details["index"], image_int8)
        interpreter.invoke()

        output_int8 = interpreter.get_tensor(output_details["index"])

        prediction = np.argmax(output_int8[0])

        if prediction == label.numpy():
            correct += 1
        total += 1

    return correct / total

acc_int8 = evaluate_int8_model(QUANT_FILE, val_ds)
# Out:
# Model Input Type: <class 'numpy.int8'>
# Input Scale: 0.007843137718737125, Zero Point: -1
# Running inference (converting float images to int8)...
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
print("\n" + "="*50)
print("        FULL INTEGER QUANTIZATION RESULTS")
print("="*50)
print(f"{'Metric':<15} | {'Base (Float32)':<15} | {'Edge (Int8)':<15}")
print("-" * 50)
print(f"{'Size':<15} | {float_size:.2f} MB         | {quant_size:.2f} MB")
print(f"{'Accuracy':<15} | (Not calculated)  | {acc_int8:.2%}")
print("-" * 50)
print(f"Compression Ratio: {float_size / quant_size:.1f}x smaller")
print("Hardware Compatibility: CPU, Edge TPU, DSP, Microcontrollers")
print("="*50)
# Out:
# ==================================================
#         FULL INTEGER QUANTIZATION RESULTS
# ==================================================
# Metric          | Base (Float32)  | Edge (Int8)
# --------------------------------------------------
# Size            | 9.25 MB         | 2.59 MB
# Accuracy        | (Not calculated)  | 88.50%
# --------------------------------------------------
# Compression Ratio: 3.6x smaller
# Hardware Compatibility: CPU, Edge TPU, DSP, Microcontrollers
# ==================================================
